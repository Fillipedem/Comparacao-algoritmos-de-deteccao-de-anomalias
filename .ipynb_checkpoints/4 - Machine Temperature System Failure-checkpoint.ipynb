# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

from helper import plot_anomalies
from Dataset import DatasetLoader
from pyanomaly.stats import MAD, Tukey
from pyanomaly.timeseries import moving_average, moving_average_score, \
                                    twitter, twitter_score

# %%
loader = DatasetLoader()
#loader.print_all()

# %%
ds_names = loader.get_list('realKnownCause')
ds_names
# Out:
# ['ambient_temperature_system_failure.csv',
#  'cpu_utilization_asg_misconfiguration.csv',
#  'ec2_request_latency_system_failure.csv',
#  'machine_temperature_system_failure.csv',
#  'nyc_taxi.csv',
#  'rogue_agent_key_hold.csv',
#  'rogue_agent_key_updown.csv']

# %% [markdown]
# ## Preprocessamento

# %%
df_raw, labels = loader.load('machine_temperature_system_failure.csv')
df_raw.head()
# Out:
#                          value
# timestamp
# 2013-12-02 21:15:00  73.967322
# 2013-12-02 21:20:00  74.935882
# 2013-12-02 21:25:00  76.124162
# 2013-12-02 21:30:00  78.140707
# 2013-12-02 21:35:00  79.329836

# %% [markdown]
# * Valores **duplicados** e **missing data**

# %%
df_raw.index.duplicated().sum()
# Out:
# 12

# %%
df_raw[df_raw.index.duplicated()]
# Out:
#                          value
# timestamp
# 2014-01-07 02:00:00  94.139723
# 2014-01-07 02:05:00  94.111970
# 2014-01-07 02:10:00  94.638723
# 2014-01-07 02:15:00  93.270907
# 2014-01-07 02:20:00  93.890249
# 2014-01-07 02:25:00  93.396627
# 2014-01-07 02:30:00  94.199300
# 2014-01-07 02:35:00  94.125420
# 2014-01-07 02:40:00  93.530827
# 2014-01-07 02:45:00  92.784720
# 2014-01-07 02:50:00  93.254724
# 2014-01-07 02:55:00  93.656042

# %%
df_raw['2014-01-07 02:00:00']
# Out:
#                          value
# timestamp
# 2014-01-07 02:00:00  94.423406
# 2014-01-07 02:00:00  94.139723

# %%
df_raw.isnull().sum()
# Out:
# value    0
# dtype: int64

# %%
df_raw.index.min(), df_raw.index.max(), df_raw.shape
# Out:
# (Timestamp('2013-12-02 21:15:00'),
#  Timestamp('2014-02-19 15:25:00'),
#  (22695, 1))

# %%
pd.date_range(start=df_raw.index.min(), end=df_raw.index.max(), freq='5T')
# Out:
# DatetimeIndex(['2013-12-02 21:15:00', '2013-12-02 21:20:00',
#                '2013-12-02 21:25:00', '2013-12-02 21:30:00',
#                '2013-12-02 21:35:00', '2013-12-02 21:40:00',
#                '2013-12-02 21:45:00', '2013-12-02 21:50:00',
#                '2013-12-02 21:55:00', '2013-12-02 22:00:00',
#                ...
#                '2014-02-19 14:40:00', '2014-02-19 14:45:00',
#                '2014-02-19 14:50:00', '2014-02-19 14:55:00',
#                '2014-02-19 15:00:00', '2014-02-19 15:05:00',
#                '2014-02-19 15:10:00', '2014-02-19 15:15:00',
#                '2014-02-19 15:20:00', '2014-02-19 15:25:00'],
#               dtype='datetime64[ns]', length=22683, freq='5T')

# %%
#drop duplicated
df = df_raw[~df_raw.index.duplicated()]
df.head()
# Out:
#                          value
# timestamp
# 2013-12-02 21:15:00  73.967322
# 2013-12-02 21:20:00  74.935882
# 2013-12-02 21:25:00  76.124162
# 2013-12-02 21:30:00  78.140707
# 2013-12-02 21:35:00  79.329836

# %%
df.shape
# Out:
# (22683, 1)

# %% [markdown]
# **Visualização**

# %%
df.plot(figsize=(20, 5))

# %%
labels
# Out:
#                 start                 end
# 0 2013-12-10 06:25:00 2013-12-12 05:35:00
# 1 2013-12-15 17:50:00 2013-12-17 17:00:00
# 2 2014-01-27 14:20:00 2014-01-29 13:30:00
# 3 2014-02-07 14:55:00 2014-02-09 14:05:00

# %% [markdown]
# ## Algoritmos

# %% [markdown]
# ### MAD

# %%
ts = df['value']

# %%
mad = MAD()
mad.fit(ts)
madpredict = mad.predict(ts)
madpredict.head()
# Out:
# timestamp
# 2013-12-04 00:10:00    64.925151
# 2013-12-04 00:20:00    65.076457
# 2013-12-04 00:25:00    64.436539
# 2013-12-04 00:30:00    64.225463
# 2013-12-04 00:35:00    64.673013
# Name: value, dtype: float64

# %%
# score por dia
mad_dayscore = madpredict.resample('D').count().dropna()/24

# %%
plot_anomalies(mad_dayscore, windows=labels)

plt.title("MAD score - Dia count",fontsize=20)
plt.ylabel('Score de anomalia');

# %% [markdown]
# ### Tukey

# %%
ts = df['value']

# %%
tu = Tukey()
tu.fit(ts)
tupredict = tu.predict(ts)
tupredict.head()
# Out:
# timestamp
# 2013-12-03 23:55:00    65.906496
# 2013-12-04 00:00:00    66.204651
# 2013-12-04 00:05:00    66.094398
# 2013-12-04 00:10:00    64.925151
# 2013-12-04 00:15:00    65.910542
# Name: value, dtype: float64

# %%
tu_dayscore = tupredict.resample('D').count().dropna()/24

# %%
plot_anomalies(tu_dayscore, windows=labels)
plt.title("Tukey score - Count do Dia",fontsize=20)
plt.ylabel('Score de anomalia', fontsize=15);

# %% [markdown]
# ### Twitter

# %%
ts = df['value']

# %%
twitterpredict = twitter(ts, period=24)
twitterpredict.head()
# Out:
# timestamp
# 2013-12-04 00:10:00    64.925151
# 2013-12-04 00:20:00    65.076457
# 2013-12-04 00:25:00    64.436539
# 2013-12-04 00:30:00    64.225463
# 2013-12-04 00:35:00    64.673013
# Name: value, dtype: float64

# %%
twitter_dayscore = twitterpredict.resample('D').count().dropna()/24

# %%
plot_anomalies(twitter_dayscore, windows=labels)
plt.title("Twitter score",fontsize=20)
plt.ylabel('Score de anomalia');

# %%
from statsmodels.tsa.seasonal import STL

# plot size
plt.rcParams['figure.figsize'] = (20, 10)
# seasonal decompose
stl = STL(ts, period=24)
results = stl.fit()
results.plot();

# %% [markdown]
# ### Forecast

# %% [markdown]
# #### ARIMA

# %%
#TODO

# %% [markdown]
# #### Holt-Winters

# %%
#TODO

# %% [markdown]
# ## Comparação por rank

# %%
from helper import top_k_precision, plot_precision_recall_curve

# %% [markdown]
# ### Resample

# %%
# Calculando top k precision para cada tecnica
mad_topk = top_k_precision(mad_dayscore, labels, k=5)
tu_topk = top_k_precision(tu_dayscore, labels, k=5)
twitter_topk = top_k_precision(twitter_dayscore, labels, k=5)

df_topk = pd.DataFrame({'mad': mad_topk,
                        'tukey': tu_topk,
                        'twitter': twitter_topk},
                        index=np.arange(1, 6))
df_topk
# Out:
#         mad     tukey   twitter
# 1  1.000000  1.000000  1.000000
# 2  0.500000  0.500000  0.500000
# 3  0.666667  0.666667  0.666667
# 4  0.750000  0.750000  0.750000
# 5  0.600000  0.600000  0.600000

# %%
fig, ax = plot_precision_recall_curve(df_topk)

# %% [markdown]
# ### Save

# %%
df_topk.index.names = ['rank']
df_topk.to_csv('./results/' + 'topk_score_' + ds_names[3])

# %%
fig.savefig('./results/' + 'topk_score_' + ds_names[3].split('.')[0] + '.jpg')
