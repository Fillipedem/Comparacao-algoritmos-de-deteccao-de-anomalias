# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

from helper import plot_anomalies
from Dataset import DatasetLoader
from pyanomaly.stats import MAD, Tukey
from pyanomaly.timeseries import moving_average, moving_average_score, \
                                    twitter, twitter_score

# %%
loader = DatasetLoader()
#loader.print_all()

# %%
ds_names = loader.get_list('realKnownCause')
ds_names
# Out:
# ['ambient_temperature_system_failure.csv',
#  'cpu_utilization_asg_misconfiguration.csv',
#  'ec2_request_latency_system_failure.csv',
#  'machine_temperature_system_failure.csv',
#  'nyc_taxi.csv',
#  'rogue_agent_key_hold.csv',
#  'rogue_agent_key_updown.csv']

# %% [markdown]
# ## Preprocessamento

# %%
df_raw, labels = loader.load('nyc_taxi.csv')
df_raw.head()
# Out:
#                      value
# timestamp
# 2014-07-01 00:00:00  10844
# 2014-07-01 00:30:00   8127
# 2014-07-01 01:00:00   6210
# 2014-07-01 01:30:00   4656
# 2014-07-01 02:00:00   3820

# %% [markdown]
# ### Valores duplicados e missing data

# %%
df_raw.index.duplicated().sum()
# Out:
# 0

# %%
df_raw.isnull().sum()
# Out:
# value    0
# dtype: int64

# %%
df_raw.index.min(), df_raw.index.max(), df_raw.shape
# Out:
# (Timestamp('2014-07-01 00:00:00'),
#  Timestamp('2015-01-31 23:30:00'),
#  (10320, 1))

# %%
drange = pd.date_range(start=df_raw.index.min(), end=df_raw.index.max(), freq='30T')
drange
# Out:
# DatetimeIndex(['2014-07-01 00:00:00', '2014-07-01 00:30:00',
#                '2014-07-01 01:00:00', '2014-07-01 01:30:00',
#                '2014-07-01 02:00:00', '2014-07-01 02:30:00',
#                '2014-07-01 03:00:00', '2014-07-01 03:30:00',
#                '2014-07-01 04:00:00', '2014-07-01 04:30:00',
#                ...
#                '2015-01-31 19:00:00', '2015-01-31 19:30:00',
#                '2015-01-31 20:00:00', '2015-01-31 20:30:00',
#                '2015-01-31 21:00:00', '2015-01-31 21:30:00',
#                '2015-01-31 22:00:00', '2015-01-31 22:30:00',
#                '2015-01-31 23:00:00', '2015-01-31 23:30:00'],
#               dtype='datetime64[ns]', length=10320, freq='30T')

# %%
df = df_raw

# %%
df.plot(figsize=(20, 5))

# %% [markdown]
# ## Algoritmos

# %% [markdown]
# ### MAD

# %%
mad = MAD()
mad.fit(df['value'])
madscore = mad.decision_function(df['value'])
madpredict = mad.predict(df['value'])
madscore.head()
# Out:
# timestamp
# 2014-07-01 00:00:00    0.979081
# 2014-07-01 00:30:00    1.427373
# 2014-07-01 01:00:00    1.743668
# 2014-07-01 01:30:00    2.000071
# 2014-07-01 02:00:00    2.138007
# Name: value, dtype: float64

# %%
plot_anomalies(madscore, windows=labels)
plt.title("MAD score - Por ponto",fontsize=20)
# Out:
# The history saving thread hit an unexpected error (OperationalError('disk I/O error')).History will not be written to the database.
# Text(0.5, 1.0, 'MAD score - Por ponto')

# %%
plot_anomalies(madscore.resample('D').mean(), windows=labels)
plt.title("MAD score - Média por Dia",fontsize=20)
# Out:
# Text(0.5, 1.0, 'MAD score - Média por Dia')

# %% [markdown]
# ### Tukey

# %%
tu = Tukey()
tu.fit(df['value'])
tupredict = tu.predict(df['value'])
tupredict.head()
# Out:
# timestamp
# 2014-11-02 01:00:00    39197
# 2014-11-02 01:30:00    35212
# Name: value, dtype: int64

# %%
tmpdf = pd.DataFrame(np.zeros(len(drange)), index=drange)
tupredict = (tmpdf[0] + tupredict).fillna(0)

# %%
fig, ax = plot_anomalies(tupredict.resample('D').mean(), windows=labels)
plt.title("Tukey score - Count do Dia",fontsize=20);

# %% [markdown]
# ### Twitter

# %%
twitterscore = twitter_score(df['value'].resample('1H').mean().dropna())
twitterscore
# Out:
# timestamp
# 2014-07-01 00:00:00    1.440419
# 2014-07-01 01:00:00    1.531668
# 2014-07-01 02:00:00    1.280671
# 2014-07-01 03:00:00    1.060900
# 2014-07-01 04:00:00    0.809556
#                          ...
# 2015-01-31 19:00:00    1.786306
# 2015-01-31 20:00:00    1.091783
# 2015-01-31 21:00:00    1.160107
# 2015-01-31 22:00:00    1.902134
# 2015-01-31 23:00:00    2.567544
# Freq: H, Length: 5160, dtype: float64

# %%
plot_anomalies(twitterscore, windows=labels)
plt.title("Twitter score - Por ponto", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Twitter score - Por ponto')

# %%
twitterday = twitterscore.resample('D').mean().dropna()

plot_anomalies(twitterday, windows=labels)
plt.title("Twitter score - Média do Dia",fontsize=20);

# %%
from statsmodels.tsa.seasonal import STL

value = df['value'].resample('1H').mean().dropna()

x = STL(value)
res = x.fit()

# %%
plt.rcParams['figure.figsize'] = 20, 10

res.plot()
res

# %%
#plt.plot(value, color='red');
new_series = (value - res.seasonal - value.median())

plt.plot(new_series, color='black')
plt.title('Output do algoritmo para o MAD', fontsize=20);

# %% [markdown]
# ### ARIMA/Holt-Winters

# %%
#TODO

# %% [markdown]
# ## Comparação por rank

# %%
from helper import top_k_precision, plot_precision_recall_curve

# %% [markdown]
# ### Resample

# %%
# Resample os dados para Dia
madscore_day = madscore.resample('D').mean().dropna()
tuscore_day = tupredict.resample('D').mean()
twitterscore_day = twitterscore.resample('D').mean().dropna()

# %%
# Calculando top k precision para cada tecnica
mad_topk = top_k_precision(madscore_day, labels, k=5)
tu_topk = top_k_precision(tuscore_day, labels, k=5)
twitter_topk = top_k_precision(twitterscore_day, labels, k=5)

df_topk = pd.DataFrame({'mad': mad_topk,
                        'tukey': tu_topk,
                        'twitter': twitter_topk},
                        index=np.arange(1, 6))
df_topk
# Out:
#         mad     tukey  twitter
# 1  1.000000  1.000000      1.0
# 2  1.000000  0.500000      1.0
# 3  0.666667  0.333333      1.0
# 4  0.750000  0.250000      1.0
# 5  0.600000  0.200000      0.8

# %%
fig, ax = plot_precision_recall_curve(df_topk)

# %% [markdown]
# ### Save

# %%
df_topk.index.names = ['rank']
df_topk.to_csv('./results/' + 'topk_score_' + ds_names[4])

# %%
fig.savefig('./results/' + 'topk_score_' + ds_names[4].split('.')[0] + '.jpg')
